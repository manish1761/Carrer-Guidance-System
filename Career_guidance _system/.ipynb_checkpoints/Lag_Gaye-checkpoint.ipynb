# %% [markdown]
# # Importing Libraries and dataset

# %%
import numpy as np
import pandas as pd

# Dataset is now stored in a Pandas Dataframe
df = pd.read_csv('career_pred.csv')

df.head()
# Out:
#    Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 0                                        69                        63
# 1                                        78                        62
# 2                                        71                        86
# 3                                        76                        87
# 4                                        92                        62
#
#    Percentage in Programming Concepts  Percentage in Software Engineering  \
# 0                                  78                                  87
# 1                                  73                                  60
# 2                                  91                                  87
# 3                                  60                                  84
# 4                                  90                                  67
#
#    Percentage in Computer Networks  Percentage in Electronics Subjects  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 39 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Acedamic percentage in Operating Systems  20000 non-null  int64
#  1   percentage in Algorithms                  20000 non-null  int64
#  2   Percentage in Programming Concepts        20000 non-null  int64
#  3   Percentage in Software Engineering        20000 non-null  int64
#  4   Percentage in Computer Networks           20000 non-null  int64
#  5   Percentage in Electronics Subjects        20000 non-null  int64
#  6   Percentage in Computer Architecture       20000 non-null  int64
#  7   Percentage in Mathematics                 20000 non-null  int64
#  8   Percentage in Communication skills        20000 non-null  int64
#  9   Hours working per day                     20000 non-null  int64
# ...

# %%
# List of column names to delete
columns_to_delete = ['Percentage in Electronics Subjects', 'can work long time before system?','workshops','Extra-courses did','talenttests taken?', 'olympiads', 'memory capability score', 'Interested subjects', 'Job/Higher Studies?', 'Type of company want to settle in?', 'Salary Range Expected','In a Realtionship?', 'Taken inputs from seniors or elders', 'Gentle or Tuff behaviour?', 'Salary/work', 'hard/smart worker',  'Introvert']

# Use the drop method to delete the specified columns
df.drop(columns=columns_to_delete, inplace=True)

# %%
df.head()
# Out:
#    Acedamic percentage in Operating Systems  percentage in Algorithms  \
# 0                                        69                        63
# 1                                        78                        62
# 2                                        71                        86
# 3                                        76                        87
# 4                                        92                        62
#
#    Percentage in Programming Concepts  Percentage in Software Engineering  \
# 0                                  78                                  87
# 1                                  73                                  60
# 2                                  91                                  87
# 3                                  60                                  84
# 4                                  90                                  67
#
#    Percentage in Computer Networks  Percentage in Computer Architecture  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 22 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Acedamic percentage in Operating Systems  20000 non-null  int64
#  1   percentage in Algorithms                  20000 non-null  int64
#  2   Percentage in Programming Concepts        20000 non-null  int64
#  3   Percentage in Software Engineering        20000 non-null  int64
#  4   Percentage in Computer Networks           20000 non-null  int64
#  5   Percentage in Computer Architecture       20000 non-null  int64
#  6   Percentage in Mathematics                 20000 non-null  int64
#  7   Percentage in Communication skills        20000 non-null  int64
#  8   Hours working per day                     20000 non-null  int64
#  9   Logical quotient rating                   20000 non-null  int64
# ...

# %%
# Define a mapping dictionary to rename columns
column_mapping = {
    
     'Acedamic percentage in Operating Systems': 'Academic percentage in Operating Systems(1%-100%)',
     'percentage in Algorithms': 'percentage in Algorithms(1%-100%)',
     'Percentage in Programming Concepts':'Percentage in Programming Concepts(1%-100%)',
     'Percentage in Software Engineering':'Percentage in Software Engineering(1%-100%)',
     'Percentage in Computer Networks':'Percentage in Computer Networks(1%-100%) ',
     'Percentage in Computer Architecture':'Percentage in Computer Architecture(1%-100%',
     'Percentage in Mathematics':'Percentage in Mathematics(1%-100%)',
     'Percentage in Communication skills':'Percentage in Communication skills(1%-100%)',
     'Hours working per day':'Hours working per day(0-12)',
     'Logical quotient rating':'Logical Reasoning Score(1-10)',
     'hackathons':'No. of hackathons',
     'coding skills rating':'coding skills rating(1-10)',
     'public speaking points':'public speaking Score(1-10)',
     'self-learning capability?':'self-learning capability?(YES/NO)',
     'certifications':'Which Programming Language/Technology of certifications you did?',
     'reading and writing skills':'reading and writing skills(EXCELLENT/MEDIUM/POOR)',
     'interested career area ':'interested career area',
     'interested in games':'interested in games(YES/NO)',
     'Interested Type of Books':'Interested Type of Books',
     'Management or Technical':'Management or Technical(Management/Technical)',
     'worked in teams ever?':'worked in teams ever?(YES/NO)',
     'Suggested Job Role': 'Suggested Job Role'
}

# Use the rename method to rename the columns
df.rename(columns=column_mapping, inplace=True)

# %%
# Get the column names
column_names = df.columns

# Convert the column names to a list if needed
column_names_list = column_names.tolist()
column_names_list
# Out:
# ['Academic percentage in Operating Systems(1%-100%)',
#  'percentage in Algorithms(1%-100%)',
#  'Percentage in Programming Concepts(1%-100%)',
#  'Percentage in Software Engineering(1%-100%)',
#  'Percentage in Computer Networks(1%-100%) ',
#  'Percentage in Computer Architecture(1%-100%',
#  'Percentage in Mathematics(1%-100%)',
#  'Percentage in Communication skills(1%-100%)',
#  'Hours working per day(0-12)',
#  'Logical Reasoning Score(1-10)',
#  'No. of hackathons',
#  'coding skills rating(1-10)',
#  'public speaking Score(1-10)',
#  'self-learning capability?(YES/NO)',
#  'Which Programming Language/Technology of certifications you did?',
#  'reading and writing skills(EXCELLENT/MEDIUM/POOR)',
#  'interested career area',
#  'interested in games(YES/NO)',
#  'Interested Type of Books',
#  'Management or Technical(Management/Technical)',
#  'worked in teams ever?(YES/NO)',
#  'Suggested Job Role']

# %%
df.head()
# Out:
#    Academic percentage in Operating Systems(1%-100%)  \
# 0                                                 69
# 1                                                 78
# 2                                                 71
# 3                                                 76
# 4                                                 92
#
#    percentage in Algorithms(1%-100%)  \
# 0                                 63
# 1                                 62
# 2                                 86
# 3                                 87
# 4                                 62
#
#    Percentage in Programming Concepts(1%-100%)  \
# 0                                           78
# 1                                           73
# 2                                           91
# 3                                           60
# 4                                           90
#
#    Percentage in Software Engineering(1%-100%)  \
# 0                                           87
# ...

# %% [markdown]
# # Data Preprocessing

# %%
#1. Handling Missing values:
df.isna()
df.isna().sum()
# Out:
# Academic percentage in Operating Systems(1%-100%)                   0
# percentage in Algorithms(1%-100%)                                   0
# Percentage in Programming Concepts(1%-100%)                         0
# Percentage in Software Engineering(1%-100%)                         0
# Percentage in Computer Networks(1%-100%)                            0
# Percentage in Computer Architecture(1%-100%                         0
# Percentage in Mathematics(1%-100%)                                  0
# Percentage in Communication skills(1%-100%)                         0
# Hours working per day(0-12)                                         0
# Logical Reasoning Score(1-10)                                       0
# No. of hackathons                                                   0
# coding skills rating(1-10)                                          0
# public speaking Score(1-10)                                         0
# ...

# %%
df=df.dropna()
df.isna().sum().sum()
# Out:
# 0

# %%
df.duplicated().sum()
df.drop_duplicates()
# Out:
#        Academic percentage in Operating Systems(1%-100%)  \
# 0                                                     69
# 1                                                     78
# 2                                                     71
# 3                                                     76
# 4                                                     92
# ...                                                  ...
# 19995                                                 83
# 19996                                                 80
# 19997                                                 83
# 19998                                                 68
# 19999                                                 73
#
#        percentage in Algorithms(1%-100%)  \
# 0                                     63
# 1                                     62
# 2                                     86
# 3                                     87
# 4                                     62
# ...

# %%
df.dtypes
# Out:
# Academic percentage in Operating Systems(1%-100%)                    int64
# percentage in Algorithms(1%-100%)                                    int64
# Percentage in Programming Concepts(1%-100%)                          int64
# Percentage in Software Engineering(1%-100%)                          int64
# Percentage in Computer Networks(1%-100%)                             int64
# Percentage in Computer Architecture(1%-100%                          int64
# Percentage in Mathematics(1%-100%)                                   int64
# Percentage in Communication skills(1%-100%)                          int64
# Hours working per day(0-12)                                          int64
# Logical Reasoning Score(1-10)                                        int64
# No. of hackathons                                                    int64
# coding skills rating(1-10)                                           int64
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Assuming your dataset is stored in a DataFrame called 'df'
# If your dataset has non-numeric columns, you may want to select only numeric columns
numeric_data = df.select_dtypes(include='number')

# Calculate the correlation matrix
correlation_matrix = numeric_data.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The resulting heatmap will show the correlation coefficients between pairs of attributes. Values closer to 1 indicate a strong positive correlation, values closer to -1 indicate a strong negative correlation, and values close to 0 indicate a weak correlation.

# %%
# Data
data = df.iloc[:,:-1].values
label = df.iloc[:,-1]

# %%
data
# Out:
# array([[69, 63, 78, ..., 'Prayer books', 'Management', 'yes'],
#        [78, 62, 73, ..., 'Childrens', 'Technical', 'no'],
#        [71, 86, 91, ..., 'Travel', 'Management', 'no'],
#        ...,
#        [83, 70, 80, ..., 'Drama', 'Technical', 'no'],
#        [68, 87, 91, ..., 'Travel', 'Management', 'yes'],
#        [73, 77, 74, ..., 'Comics', 'Management', 'yes']], dtype=object)

# %%
label
# Out:
# 0                               Database Developer
# 1                             Portal Administrator
# 2                             Portal Administrator
# 3                   Systems Security Administrator
# 4                         Business Systems Analyst
#                            ...
# 19995                           Technical Engineer
# 19996                           E-Commerce Analyst
# 19997                Business Intelligence Analyst
# 19998    Software Quality Assurance (QA) / Testing
# 19999                       Applications Developer
# Name: Suggested Job Role, Length: 20000, dtype: object

# %%
label.nunique()
# Out:
# 34

# %%
df.head()
# Out:
#    Academic percentage in Operating Systems(1%-100%)  \
# 0                                                 69
# 1                                                 78
# 2                                                 71
# 3                                                 76
# 4                                                 92
#
#    percentage in Algorithms(1%-100%)  \
# 0                                 63
# 1                                 62
# 2                                 86
# 3                                 87
# 4                                 62
#
#    Percentage in Programming Concepts(1%-100%)  \
# 0                                           78
# 1                                           73
# 2                                           91
# 3                                           60
# 4                                           90
#
#    Percentage in Software Engineering(1%-100%)  \
# 0                                           87
# ...

# %% [markdown]
# # Label Encoding and Normalizing the data

# %%
# function to Encode the label into numeric
from sklearn.preprocessing import LabelEncoder

def Label_Encode(label):
    le = LabelEncoder()
    original=label.unique()
    label2 = le.fit_transform(label)
    y=pd.DataFrame(label2,columns=["Suggested Job Role"])
    numeric=y["Suggested Job Role"].unique() 
    Y = pd.DataFrame({'Suggested Job Role':original, 'Associated Number':numeric})
    return Y

# %%
Y= Label_Encode(label)
Y
# Out:
#                            Suggested Job Role  Associated Number
# 0                          Database Developer                  7
# 1                        Portal Administrator                 18
# 2              Systems Security Administrator                 28
# 3                    Business Systems Analyst                  2
# 4                   Software Systems Engineer                 25
# 5               Business Intelligence Analyst                  1
# 6                     CRM Technical Developer                  4
# 7               Mobile Applications Developer                 14
# 8                                 UX Designer                 32
# 9                 Quality Assurance Associate                 21
# 10                              Web Developer                 33
# 11               Information Security Analyst                 11
# 12                       CRM Business Analyst                  3
# ...

# %%
le = LabelEncoder()
original=label.unique()
label2 = le.fit_transform(label)
y=pd.DataFrame(label2,columns=["Suggested Job Role"])

# %%
y
# Out:
#        Suggested Job Role
# 0                       7
# 1                      18
# 2                      18
# 3                      28
# 4                       2
# ...                   ...
# 19995                  29
# 19996                  10
# 19997                   1
# 19998                  24
# 19999                   0
#
# [20000 rows x 1 columns]

# %%
#Label Encoding: Converting To Numeric values
#Normalizing the data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, Normalizer

# function to Encode the data into numeric
def Data_Encode(data):
    labelencoder = LabelEncoder()
    for i in range(13,21):
        data[:,i] = labelencoder.fit_transform(data[:,i])
    return data

# %%
df.head()
# Out:
#    Academic percentage in Operating Systems(1%-100%)  \
# 0                                                 69
# 1                                                 78
# 2                                                 71
# 3                                                 76
# 4                                                 92
#
#    percentage in Algorithms(1%-100%)  \
# 0                                 63
# 1                                 62
# 2                                 86
# 3                                 87
# 4                                 62
#
#    Percentage in Programming Concepts(1%-100%)  \
# 0                                           78
# 1                                           73
# 2                                           91
# 3                                           60
# 4                                           90
#
#    Percentage in Software Engineering(1%-100%)  \
# 0                                           87
# ...

# %%
print(Data_Encode(data))
# Out:
# [[69 63 78 ... 21 0 1]
#  [78 62 73 ... 5 1 0]
#  [71 86 91 ... 29 0 0]
#  ...
#  [83 70 80 ... 10 1 0]
#  [68 87 91 ... 29 0 1]
#  [73 77 74 ... 6 0 1]]

# %%
df.head()
# Out:
#    Academic percentage in Operating Systems(1%-100%)  \
# 0                                                 69
# 1                                                 78
# 2                                                 71
# 3                                                 76
# 4                                                 92
#
#    percentage in Algorithms(1%-100%)  \
# 0                                 63
# 1                                 62
# 2                                 86
# 3                                 87
# 4                                 62
#
#    Percentage in Programming Concepts(1%-100%)  \
# 0                                           78
# 1                                           73
# 2                                           91
# 3                                           60
# 4                                           90
#
#    Percentage in Software Engineering(1%-100%)  \
# 0                                           87
# ...

# %%
data = Data_Encode(data)

# %%
data.shape
# Out:
# (20000, 21)

# %%
data1=data[:,:13]
normalized_data1 = Normalizer().fit_transform(data1)

data2=data[:,13:]
normalized_data2 = Normalizer().fit_transform(data2)

df1 = np.append(normalized_data1,normalized_data2,axis=1)

# %%
df1
# Out:
# array([[0.3093766 , 0.28247429, 0.34973008, ..., 0.91826589, 0.        ,
#         0.04372695],
#        [0.36863469, 0.29301732, 0.34500426, ..., 0.6681531 , 0.13363062,
#         0.        ],
#        [0.3132895 , 0.37947742, 0.40154006, ..., 0.99469179, 0.        ,
#         0.        ],
#        ...,
#        [0.36644681, 0.30905153, 0.35320174, ..., 0.90909091, 0.09090909,
#         0.        ],
#        [0.31124297, 0.39820791, 0.41651632, ..., 0.98037894, 0.        ,
#         0.03380617],
#        [0.32411809, 0.34187799, 0.32855806, ..., 0.75592895, 0.        ,
#         0.12598816]])

# %% [markdown]
# # Data Integration

# %%
#Combining into a dataset
df2=df.iloc[:,:-1]
dataset = pd.DataFrame(df1,columns=df2.columns)
dataset
# Out:
#        Academic percentage in Operating Systems(1%-100%)  \
# 0                                               0.309377
# 1                                               0.368635
# 2                                               0.313290
# 3                                               0.345630
# 4                                               0.430174
# ...                                                  ...
# 19995                                           0.387876
# 19996                                           0.358093
# 19997                                           0.366447
# 19998                                           0.311243
# 19999                                           0.324118
#
#        percentage in Algorithms(1%-100%)  \
# 0                               0.282474
# 1                               0.293017
# 2                               0.379477
# 3                               0.395655
# 4                               0.289900
# ...

# %%
df['Which Programming Language/Technology of certifications you did?'].nunique()
# Out:
# 9

# %%
df['Which Programming Language/Technology of certifications you did?'].unique()
# Out:
# array(['shell programming', 'machine learning', 'app development',
#        'python', 'r programming', 'information security', 'hadoop',
#        'distro making', 'full stack'], dtype=object)

# %% [markdown]
# # Training and Testing

# %%
X = dataset.copy()
X
# Out:
#        Academic percentage in Operating Systems(1%-100%)  \
# 0                                               0.309377
# 1                                               0.368635
# 2                                               0.313290
# 3                                               0.345630
# 4                                               0.430174
# ...                                                  ...
# 19995                                           0.387876
# 19996                                           0.358093
# 19997                                           0.366447
# 19998                                           0.311243
# 19999                                           0.324118
#
#        percentage in Algorithms(1%-100%)  \
# 0                               0.282474
# 1                               0.293017
# 2                               0.379477
# 3                               0.395655
# 4                               0.289900
# ...

# %%
y
# Out:
#        Suggested Job Role
# 0                       7
# 1                      18
# 2                      18
# 3                      28
# 4                       2
# ...                   ...
# 19995                  29
# 19996                  10
# 19997                   1
# 19998                  24
# 19999                   0
#
# [20000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing 
from sklearn.metrics import accuracy_score

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=10)

# %%
X_train.head()
# Out:
#        Academic percentage in Operating Systems(1%-100%)  \
# 18660                                           0.347875
# 10831                                           0.377987
# 5511                                            0.397737
# 3543                                            0.304139
# 12340                                           0.305053
#
#        percentage in Algorithms(1%-100%)  \
# 18660                           0.404405
# 10831                           0.382896
# 5511                            0.305951
# 3543                            0.371228
# 12340                           0.300286
#
#        Percentage in Programming Concepts(1%-100%)  \
# 18660                                     0.369618
# 10831                                     0.441803
# 5511                                      0.327805
# 3543                                      0.304139
# 12340                                     0.433747
#
# ...

# %%
X_test.head()
# Out:
#        Academic percentage in Operating Systems(1%-100%)  \
# 19778                                           0.394191
# 4376                                            0.362837
# 10188                                           0.366934
# 9887                                            0.376047
# 4441                                            0.386519
#
#        percentage in Algorithms(1%-100%)  \
# 19778                           0.332184
# 4376                            0.287767
# 10188                           0.284374
# 9887                            0.398701
# 4441                            0.299092
#
#        Percentage in Programming Concepts(1%-100%)  \
# 19778                                     0.323326
# 4376                                      0.287767
# 10188                                     0.275200
# 9887                                      0.335271
# 4441                                      0.340504
#
# ...

# %%
y_train.head()
# Out:
#        Suggested Job Role
# 18660                  16
# 10831                   4
# 5511                   28
# 3543                   11
# 12340                   3

# %%
y_test.head()
# Out:
#        Suggested Job Role
# 19778                  24
# 4376                   24
# 10188                  10
# 9887                    5
# 4441                    9

# %%
X_train.shape
# Out:
# (16000, 21)

# %%
X_test.shape
# Out:
# (4000, 21)

# %%
y_train.shape
# Out:
# (16000, 1)

# %%
y_test.shape
# Out:
# (4000, 1)

# %% [markdown]
# # Model Selection

# %% [markdown]
# # 1. Decision Tree

# %%
#Decision Tree Classifier
from sklearn import tree
from sklearn.metrics import accuracy_score

def Decision_Tree(X_train,X_test,y_train,y_test):
    DT_model = tree.DecisionTreeClassifier()
    DT_model = DT_model.fit(X_train, y_train)
    
    # Prediction
    y_pred = DT_model.predict(X_test)
    y_test_arr=y_test['Suggested Job Role']
    Final = pd.DataFrame({'Predicted':y_pred, 'Actual':y_test_arr})
    Final.reset_index()
    
    accuracy = accuracy_score(y_test,y_pred)
    accuracy = accuracy*100
    #print("accuracy=",accuracy*100)

    #Number of correct predicted
    comparison_column = np.where(Final['Predicted'] == Final['Actual'], 1, 0)
    Number_of_correct_predictions=list(comparison_column).count(1)
    #print("Number_of_correct_predictions : ",((Number_of_correct_predictions)/4000)*100,"%")
    accuracy_DT=Number_of_correct_predictions
    #print(accuracy_DT)
    return DT_model

# %%
# Decision_Tree(X_train,X_test,y_train,y_test)

# %% [markdown]
# # 2. Support Vector Machine

# %%
# Run svm with default hyper parameters
# Default hyperparameter means C=1.0, kernel=rbf and gamma=auto among other parameters
# import SVC classifier
from sklearn.svm import SVC

# import metrics to compute accuracy
from sklearn.metrics import accuracy_score

def S_V_M(X_train,X_test,y_train,y_test):
    
    # instantiate classifier with default hyperparameters
    svc=SVC() 

    # Ensure that the target variables are 1-dimensional numpy arrays
    y_train = y_train.to_numpy().ravel()
    y_test = y_test.to_numpy().ravel()

    # fit classifier to training set
    svc.fit(X_train,y_train)

    # make predictions on test set
    y_pred=svc.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)*100
    # compute and print accuracy score
    #print('Model accuracy score with default hyperparameters: {0:0.4f}'.format(accuracy_score(y_test, y_pred)*100))
    
    return svc

# %%
# S_V_M(X_train,X_test,y_train,y_test)

# %% [markdown]
# # XGBOOST

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

def XG_BOOST(X_train,X_test,y_train,y_test):
    # fit model on training data
    model = XGBClassifier()
    model.fit(X_train, y_train)

    # make predictions on the test set (assuming you have X_test and y_test)
    y_pred = model.predict(X_test)

    # compute and print accuracy score
    accuracy = accuracy_score(y_test, y_pred)
    #print(f'Model accuracy score: {accuracy * 100:.4f}')
    
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    #print(accuracy)
    
    return model

# %%
# XG_BOOST(X_train,X_test,y_train,y_test)

# %% [markdown]
# # Used Models

# %%
decision_tree_model = Decision_Tree(X_train,X_test,y_train,y_test)
svc_model = S_V_M(X_train,X_test,y_train,y_test) 
xg_boost_model = XG_BOOST(X_train,X_test,y_train,y_test)

# %% [markdown]
# So, SVM has highest Accuuracy and hence is best suited.

# %% [markdown]
# # Comparing the Accuracies of Various Algorithms

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
Name = ['Decision Tree', 'SVM', 'XGBoost']
accuracies = [3.125,5.6,3.3000]
ax.bar(Name,accuracies)
ax.set_ylabel('Accuracies')
ax.set_xlabel('Techniques')
plt.show()

# %%
X
# Out:
#        Academic percentage in Operating Systems(1%-100%)  \
# 0                                               0.309377
# 1                                               0.368635
# 2                                               0.313290
# 3                                               0.345630
# 4                                               0.430174
# ...                                                  ...
# 19995                                           0.387876
# 19996                                           0.358093
# 19997                                           0.366447
# 19998                                           0.311243
# 19999                                           0.324118
#
#        percentage in Algorithms(1%-100%)  \
# 0                               0.282474
# 1                               0.293017
# 2                               0.379477
# 3                               0.395655
# 4                               0.289900
# ...

# %% [markdown]
# # Check with User Inputs

# %%
x_new = []
# feat = list(X.columns) 
# for i in feat:
#   print(i)
#   val = input("Enter: ") 
#   x_new.append(val)
# x_new

x_new = ['90',
 '90',
 '89',
 '78',
 '89',
 '89',
 '99',
 '89',
 '6',
 '8',
 '9',
 '9',
 '9',
 'yes',
 'python',
 'medium',
 'data science',
 'yes',
 'comedy',
 'technical',
 'yes']

# %%
# #Label Encoding: Converting To Numeric values
# #Normalizing the data
# from sklearn.preprocessing import LabelEncoder, OneHotEncoder, Normalizer

# # function to Encode the data into numeric
# def Data_Encode_for_input(input_data):
#     labelencoder = LabelEncoder()
#     for i in range(1,21):
#         input_data[:,i] = labelencoder.fit_transform(input_data[:,i])
#     return data

# data = Data_Encode_for_input(x_new)

# data1_input=data[:,:]
# normalized_input_data1 = Normalizer().fit_transform(data1_input)

# %%
import numpy as np
from sklearn.preprocessing import LabelEncoder, Normalizer

x_new = ['90', '90', '89', '78', '89', '89', '99', '89', '6', '8', '9', '9', '9', 'yes', 'python', 'medium', 'data science', 'yes', 'comedy', 'technical', 'yes']

# Convert string elements to integers for label encoding
x_new_encoded = []
for i in range(len(x_new)):
    if i < 14 or i == 18:
        try:
            x_new_encoded.append(int(x_new[i]))
        except ValueError:
            x_new_encoded.append(x_new[i])
    else:
        x_new_encoded.append(x_new[i])

# Convert to NumPy array for label encoding
x_new_array = np.array(x_new_encoded).reshape(1, -1)

# Label encoding
label_encoder = LabelEncoder()
x_new_encoded = label_encoder.fit_transform(x_new_array.ravel())

# Reshape back to the original shape
x_new_encoded = x_new_encoded.reshape(x_new_array.shape)

# Normalizing the data
normalized_input_data = Normalizer().fit_transform(x_new_encoded)

print(normalized_input_data)
# Out:
# [[0.15640281 0.15640281 0.09384169 0.03128056 0.09384169 0.09384169
#   0.18768337 0.09384169 0.         0.06256112 0.12512225 0.12512225
#   0.12512225 0.37536675 0.31280562 0.28152506 0.2502445  0.37536675
#   0.21896394 0.34408619 0.37536675]]

# %%
normalized_input_data.shape
# Out:
# (1, 21)

# %%
Y
# Out:
#                            Suggested Job Role  Associated Number
# 0                          Database Developer                  7
# 1                        Portal Administrator                 18
# 2              Systems Security Administrator                 28
# 3                    Business Systems Analyst                  2
# 4                   Software Systems Engineer                 25
# 5               Business Intelligence Analyst                  1
# 6                     CRM Technical Developer                  4
# 7               Mobile Applications Developer                 14
# 8                                 UX Designer                 32
# 9                 Quality Assurance Associate                 21
# 10                              Web Developer                 33
# 11               Information Security Analyst                 11
# 12                       CRM Business Analyst                  3
# ...

# %%
y
# Out:
#        Suggested Job Role
# 0                       7
# 1                      18
# 2                      18
# 3                      28
# 4                       2
# ...                   ...
# 19995                  29
# 19996                  10
# 19997                   1
# 19998                  24
# 19999                   0
#
# [20000 rows x 1 columns]

# %%
Y['Associated Number']
# Out:
# 0      7
# 1     18
# 2     28
# 3      2
# 4     25
# 5      1
# 6      4
# 7     14
# 8     32
# 9     21
# 10    33
# 11    11
# 12     3
# 13    31
# 14    20
# 15    13
# 16    19
# 17     9
# 18    26
# 19    27
# 20    16
# 21     5
# 22    22
# 23    10
# 24    30
# 25    12
# 26     8
# 27     0
# 28     6
# 29    15
# 30    23
# 31    29
# 32    17
# 33    24
# Name: Associated Number, dtype: int32

# %%
input_data__ = pd.DataFrame(normalized_input_data, columns=['Academic percentage in Operating Systems(1%-100%)',
 'percentage in Algorithms(1%-100%)',
 'Percentage in Programming Concepts(1%-100%)',
 'Percentage in Software Engineering(1%-100%)',
 'Percentage in Computer Networks(1%-100%) ',
 'Percentage in Computer Architecture(1%-100%',
 'Percentage in Mathematics(1%-100%)',
 'Percentage in Communication skills(1%-100%)',
 'Hours working per day(0-12)',
 'Logical Reasoning Score(1-10)',
 'No. of hackathons',
 'coding skills rating(1-10)',
 'public speaking Score(1-10)',
 'self-learning capability?(YES/NO)',
 'Which Programming Language/Technology of certifications you did?',
 'reading and writing skills(EXCELLENT/MEDIUM/POOR)',
 'interested career area',
 'interested in games(YES/NO)',
 'Interested Type of Books',
 'Management or Technical(Management/Technical)',
 'worked in teams ever?(YES/NO)'])

# %%
new_pred  = svc_model.predict(input_data__)
print("Prediction : {}".format(Y[Y['Associated Number']==new_pred[0]]['Suggested Job Role']))
# Out:
# Prediction : 20    Network Security Administrator
# Name: Suggested Job Role, dtype: object

# %%
new_pred
# Out:
# array([16])

# %% [markdown]
# # Serialize and save the model to a file

# %%
import pickle
model  = pickle.load(open('svc.pkl','rb'))

# %%
result = model.predict(input_data__)
print("Prediction : {}".format(Y[Y['Associated Number']==result[0]]['Suggested Job Role']))
# Out:
# Prediction : 20    Network Security Administrator
# Name: Suggested Job Role, dtype: object

# %%
result[0]
# Out:
# 16

# %%
Y['Associated Number']==16
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# Name: Associated Number, dtype: bool

# %%
k = Y[Y['Associated Number']==result[0]]['Suggested Job Role']
k
# Out:
# 20    Network Security Administrator
# Name: Suggested Job Role, dtype: object

# %%
Y
# Out:
#                            Suggested Job Role  Associated Number
# 0                          Database Developer                  7
# 1                        Portal Administrator                 18
# 2              Systems Security Administrator                 28
# 3                    Business Systems Analyst                  2
# 4                   Software Systems Engineer                 25
# 5               Business Intelligence Analyst                  1
# 6                     CRM Technical Developer                  4
# 7               Mobile Applications Developer                 14
# 8                                 UX Designer                 32
# 9                 Quality Assurance Associate                 21
# 10                              Web Developer                 33
# 11               Information Security Analyst                 11
# 12                       CRM Business Analyst                  3
# ...

# %%
Y.to_csv('Yfile.csv', index=False)

# %%
import numpy as np
import pandas as pd

# Dataset is now stored in a Pandas Dataframe
Dff = pd.read_csv('Yfile.csv')
Dff.head()
# Out:
#                Suggested Job Role  Associated Number
# 0              Database Developer                  7
# 1            Portal Administrator                 18
# 2  Systems Security Administrator                 28
# 3        Business Systems Analyst                  2
# 4       Software Systems Engineer                 25
